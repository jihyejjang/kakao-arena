# %% [markdown]
# # 0809
# # 클러스터링으로 tag 채워보기
# - 노래 O 태그 X
# - 노래 X 태그 O
# - 노래 O 태그 O
# - 노래 X 태그 X
#
# #### 그외 아이디어
# - 가수 이름과 관련된 태그?
#
# #### 수정사항
# - 많이나온 순으로 했을 때 count 같은거 어떻게 계산?
# ---
#
# 우선 **`노래 X 태그 O`** 인 경우에 대해서 시도할 예정
#
# ---
#
# ## 결과 요약
# ### **`노래 X 태그 O`**에도 종류가 많았음
#
# - 1. 태그가 1개 있는데 그 태그가 train에 존재
#     - 놀랍게도 **0건**^^
#
# - 2. **태그가 1개 있는데 그 태그가 train에 존재하지 않음** `error_list`
#
# - 3. 태그가 2~9개 있는데 그중 하나라도 train에 존재
#     - 나머지 태그중 가장 많이 나온 집합에서 상위 태그 넣었다.
#
# - 4. **태그가 2~9개 있는데 모두다 train에 없음** `error_list3`
#
# - 5. 태그가 10개가 채워져 있음
#
# #### 2,4번은 어케해결하지..?
# 일단 3번만 했다. `perform`이 수행한 거 목록
#
#
#
# ---
#
# # 1. Data 불러오기

# %%
from sklearn import datasets
import pandas as pd
import json
import re # regular expression
import gc # to collect memory
from datetime import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import matplotlib
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
# load json files
with open("./res/genre_gn_all.json", encoding = 'utf-8') as json_file: genre_gn_all = json.load(json_file)
#with open("./res/song_meta.json", encoding = 'utf-8') as json_file: song_meta = json.load(json_file)
#with open("./res/train.json", encoding = 'utf-8') as json_file: train = json.load(json_file)
with open("./res/val.json", encoding = 'utf-8') as json_file: valid = json.load(json_file)

# json to dataframe
genre_gn_all = pd.Series(genre_gn_all).to_frame('genre').reset_index().rename({'index' : 'gen_id'}, axis = 1)
song_meta = pd.read_json('./res/song_meta_cnt.json', orient='table')
train = pd.read_json('./res/train_topgnr.json', orient='table')
valid = pd.DataFrame(valid)
tag_cnt=pd.read_json('./res/tag_cnt.json', orient='table')

#지민이가 준 파일 table로 안불러짐.... frame으로 하면 열리긴 하지만 내용깨짐
#song_artist_tag=pd.read_json('./res/song_artist_tag.json', orient='table')

tag_tf_gnrmap=pd.read_json('./res/tag_tf_gnrmap.json', orient='table')

# %% [markdown]
# # 2. k-means Clustering

# %%
from sklearn.cluster import KMeans

# %%
tag_tf_gnrmap
# Out:
#          tags  mapping_cnt  GN0100  GN0200  GN0300  GN0400  GN0500  GN0600  \
# 0                        1   False   False   False   False   False   False
# 1          00            4   False    True    True   False   False   False
# 2         007            3   False   False   False   False   False   False
# 3      007시리즈            2   False   False   False   False   False   False
# 4         00s            3    True   False   False   False   False   False
# ...       ...          ...     ...     ...     ...     ...     ...     ...
# 29155      힙해            5   False   False    True   False   False   False
# 29156     힙힙힙            2   False   False    True    True   False   False
# 29157    힛뎀포크            1   False   False   False   False   False   False
# 29158     힛뎀폭            1   False   False   False   False   False   False
# 29159    힛뎀폭스            2   False   False   False   False   False   False
#
#        GN0700  GN0800  ...  GN2200  GN2300  GN2400  GN2500  GN2600  GN2700  \
# 0       False   False  ...   False   False   False   False   False   False
# 1       False   False  ...   False   False   False   False   False   False
# 2       False   False  ...   False   False   False   False   False   False
# 3       False   False  ...   False   False   False   False   False   False
# 4       False   False  ...   False   False   False   False   False   False
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 29155   False   False  ...   False   False   False   False   False   False
# 29156   False   False  ...   False   False   False   False   False   False
# 29157   False   False  ...   False   False   False   False   False   False
# 29158   False   False  ...   False   False   False   False   False   False
# 29159   False   False  ...   False   False   False   False   False   False
#
#        GN2800  GN2900  GN3000  GN9000
# 0       False   False   False   False
# 1       False   False   False   False
# 2       False   False   False   False
# 3       False   False   False   False
# 4       False   False   False   False
# ...       ...     ...     ...     ...
# 29155   False   False   False   False
# 29156   False   False   False   False
# 29157   False   False   False   False
# 29158   False   False   False   False
# 29159   False   False   False   False
#
# [29160 rows x 33 columns]

# %%
feature=tag_tf_gnrmap[['GN0100','GN0200','GN0300','GN0400','GN0500','GN0600','GN0700','GN0800','GN0900','GN1000',
                        'GN1100','GN1200','GN1300','GN1400','GN1500','GN1600','GN1700','GN1800','GN1900','GN2000',
                       'GN2100','GN2200','GN2300','GN2400','GN2500','GN2600','GN2700','GN2800','GN2900','GN3000','GN9000']]
feature
# Out:
#        GN0100  GN0200  GN0300  GN0400  GN0500  GN0600  GN0700  GN0800  GN0900  \
# 0       False   False   False   False   False   False   False   False   False
# 1       False    True    True   False   False   False   False   False    True
# 2       False   False   False   False   False   False   False   False    True
# 3       False   False   False   False   False   False   False   False    True
# 4        True   False   False   False   False   False   False   False   False
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 29155   False   False    True   False   False   False   False   False    True
# 29156   False   False    True    True   False   False   False   False   False
# 29157   False   False   False   False   False   False   False   False   False
# 29158   False   False   False   False   False   False   False   False   False
# 29159   False   False   False   False   False   False   False   False   False
#
#        GN1000  ...  GN2200  GN2300  GN2400  GN2500  GN2600  GN2700  GN2800  \
# 0       False  ...   False   False   False   False   False   False   False
# 1       False  ...   False   False   False   False   False   False   False
# 2       False  ...   False   False   False   False   False   False   False
# 3       False  ...   False   False   False   False   False   False   False
# 4       False  ...   False   False   False   False   False   False   False
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 29155   False  ...   False   False   False   False   False   False   False
# 29156   False  ...   False   False   False   False   False   False   False
# 29157   False  ...   False   False   False   False   False   False   False
# 29158   False  ...   False   False   False   False   False   False   False
# 29159   False  ...   False   False   False   False   False   False   False
#
#        GN2900  GN3000  GN9000
# 0       False   False   False
# 1       False   False   False
# 2       False   False   False
# 3       False   False   False
# 4       False   False   False
# ...       ...     ...     ...
# 29155   False   False   False
# 29156   False   False   False
# 29157   False   False   False
# 29158   False   False   False
# 29159   False   False   False
#
# [29160 rows x 31 columns]

# %%
model = KMeans(n_clusters=100,algorithm='auto')
model.fit(feature)
predict = pd.DataFrame(model.predict(feature))
predict.columns=['predict']

# %%
r = pd.concat([feature,predict],axis=1)

# %%
labels = model.labels_
centers = model.cluster_centers_

# %%
tag_tf_gnrmap['labels']=labels

# %%
tag_tf_gnrmap
#라벨이 추가된걸 확인 가능하다.
# Out:
#          tags  mapping_cnt  GN0100  GN0200  GN0300  GN0400  GN0500  GN0600  \
# 0                        1   False   False   False   False   False   False
# 1          00            4   False    True    True   False   False   False
# 2         007            3   False   False   False   False   False   False
# 3      007시리즈            2   False   False   False   False   False   False
# 4         00s            3    True   False   False   False   False   False
# ...       ...          ...     ...     ...     ...     ...     ...     ...
# 29155      힙해            5   False   False    True   False   False   False
# 29156     힙힙힙            2   False   False    True    True   False   False
# 29157    힛뎀포크            1   False   False   False   False   False   False
# 29158     힛뎀폭            1   False   False   False   False   False   False
# 29159    힛뎀폭스            2   False   False   False   False   False   False
#
#        GN0700  GN0800  ...  GN2300  GN2400  GN2500  GN2600  GN2700  GN2800  \
# 0       False   False  ...   False   False   False   False   False   False
# 1       False   False  ...   False   False   False   False   False   False
# 2       False   False  ...   False   False   False   False   False   False
# 3       False   False  ...   False   False   False   False   False   False
# 4       False   False  ...   False   False   False   False   False   False
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 29155   False   False  ...   False   False   False   False   False   False
# 29156   False   False  ...   False   False   False   False   False   False
# 29157   False   False  ...   False   False   False   False   False   False
# 29158   False   False  ...   False   False   False   False   False   False
# 29159   False   False  ...   False   False   False   False   False   False
#
#        GN2900  GN3000  GN9000  labels
# 0       False   False   False      10
# 1       False   False   False      99
# 2       False   False   False       0
# 3       False   False   False       6
# 4       False   False   False       4
# ...       ...     ...     ...     ...
# 29155   False   False   False      40
# 29156   False   False   False       8
# 29157   False   False   False      10
# 29158   False   False   False      10
# 29159   False   False   False      10
#
# [29160 rows x 34 columns]

# %%
#정렬
tag_tf_gnrmap=tag_tf_gnrmap.sort_values('mapping_cnt', ascending = False)
tag_tf_gnrmap
# Out:
#             tags  mapping_cnt  GN0100  GN0200  GN0300  GN0400  GN0500  GN0600  \
# 7065        기분전환        16465    True    True    True    True    True    True
# 5234          감성        11417    True    True    True    True    True    True
# 28675         휴식        11215    True    True    True    True    True    True
# 12894        발라드        10796    True    True    True    True    True    True
# 22262        잔잔한        10218    True    True    True    True    True    True
# ...          ...          ...     ...     ...     ...     ...     ...     ...
# 24860         춥고            1   False   False   False   False    True   False
# 21635  인더스트리얼테크노            1   False   False   False   False   False   False
# 24857        춤추며            1   False    True   False   False   False   False
# 24856    춤추기좋은팝송            1   False   False   False   False   False   False
# 14580       삐걱삐걱            1   False   False    True   False   False   False
#
#        GN0700  GN0800  ...  GN2300  GN2400  GN2500  GN2600  GN2700  GN2800  \
# 7065     True    True  ...   False    True    True    True    True    True
# 5234     True    True  ...   False    True    True    True    True    True
# 28675    True    True  ...    True    True    True    True   False    True
# 12894    True    True  ...   False    True    True   False   False   False
# 22262    True    True  ...    True    True    True    True    True    True
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 24860   False   False  ...   False   False   False   False   False   False
# 21635   False   False  ...   False   False   False   False   False   False
# 24857   False   False  ...   False   False   False   False   False   False
# 24856   False   False  ...   False   False   False   False   False   False
# 14580   False   False  ...   False   False   False   False   False   False
#
#        GN2900  GN3000  GN9000  labels
# 7065     True   False   False      26
# 5234    False   False    True      26
# 28675    True   False    True      26
# 12894   False   False   False      98
# 22262   False   False    True      26
# ...       ...     ...     ...     ...
# 24860   False   False   False       1
# 21635   False   False   False       5
# 24857   False   False   False      13
# 24856   False   False   False       5
# 14580   False   False   False      14
#
# [29160 rows x 34 columns]

# %%
tag_tf_gnrmap.loc[tag_tf_gnrmap['labels']==11].head(10)
# Out:
#         tags  mapping_cnt  GN0100  GN0200  GN0300  GN0400  GN0500  GN0600  \
# 28187    협주곡           39   False   False   False   False   False   False
# 6386     교향곡           36   False   False   False   False   False   False
# 16377    스코어           34   False   False   False   False   False   False
# 15493     성악           32   False   False   False   False   False   False
# 12749     바흐           32   False   False   False   False   False   False
# 25673  클래식명곡           32   False   False   False   False   False   False
# 13351    베토벤           32   False   False   False   False   False   False
# 15976     쇼팽           30   False   False   False   False   False   False
# 11924     명연           28   False   False   False   False   False   False
# 7015      기도           28   False   False   False   False   False   False
#
#        GN0700  GN0800  ...  GN2300  GN2400  GN2500  GN2600  GN2700  GN2800  \
# 28187   False   False  ...   False   False   False   False   False   False
# 6386    False   False  ...   False   False   False   False   False   False
# 16377   False   False  ...   False   False   False   False   False   False
# 15493   False   False  ...   False   False   False   False   False   False
# 12749   False   False  ...   False   False   False   False   False   False
# 25673   False   False  ...   False   False   False   False   False   False
# 13351   False   False  ...   False   False   False   False   False   False
# 15976   False   False  ...   False   False   False   False   False   False
# 11924   False   False  ...   False   False   False   False   False   False
# 7015    False   False  ...   False   False   False   False   False   False
#
#        GN2900  GN3000  GN9000  labels
# 28187   False   False   False      11
# 6386    False   False   False      11
# 16377   False   False   False      11
# 15493   False   False   False      11
# 12749   False   False   False      11
# 25673   False   False   False      11
# 13351   False   False   False      11
# 15976   False   False   False      11
# 11924   False   False   False      11
# 7015    False   False   False      11
#
# [10 rows x 34 columns]

# %%
tag_tf_gnrmap_count=tag_tf_gnrmap.groupby('labels').tags.nunique().reset_index(name='count')
tag_tf_gnrmap_count.head(50)
# Out:
#     labels  count
# 0        0    145
# 1        1   1665
# 2        2   1719
# 3        3     51
# 4        4   3257
# 5        5   1571
# 6        6   2818
# 7        7     83
# 8        8    461
# 9        9    590
# 10      10    993
# 11      11   1240
# 12      12    967
# 13      13    749
# 14      14   1137
# 15      15    976
# 16      16    143
# 17      17   1332
# 18      18     64
# 19      19    352
# 20      20    413
# 21      21     35
# 22      22    347
# 23      23    640
# 24      24     52
# 25      25     43
# 26      26     61
# 27      27     48
# 28      28     44
# 29      29     53
# 30      30    270
# 31      31    280
# 32      32    367
# 33      33     49
# 34      34     68
# 35      35    108
# 36      36     47
# 37      37    294
# 38      38    242
# 39      39    151
# 40      40    169
# 41      41     69
# 42      42     36
# 43      43     43
# 44      44    117
# 45      45     74
# 46      46    240
# 47      47    145
# 48      48    133
# 49      49     68

# %%
tag_tf_gnrmap_count.tail(50)
# Out:
#     labels  count
# 50      50     45
# 51      51     92
# 52      52     77
# 53      53    238
# 54      54     75
# 55      55     32
# 56      56    125
# 57      57     97
# 58      58     65
# 59      59    139
# 60      60     91
# 61      61     50
# 62      62    189
# 63      63     47
# 64      64    111
# 65      65     45
# 66      66     50
# 67      67    188
# 68      68    187
# 69      69    158
# 70      70     85
# 71      71     47
# 72      72    108
# 73      73     39
# 74      74     30
# 75      75     80
# 76      76     46
# 77      77     60
# 78      78     68
# 79      79    106
# 80      80    105
# 81      81     54
# 82      82     49
# 83      83    128
# 84      84     55
# 85      85     60
# 86      86     43
# 87      87     99
# 88      88     81
# 89      89     86
# 90      90     56
# 91      91    100
# 92      92     55
# 93      93     50
# 94      94     14
# 95      95    102
# 96      96     52
# 97      97     26
# 98      98     32
# 99      99    124

# %% [markdown]
# ### 100개로 나뉘었고, 가장적은게 14개인걸로 봐서 10개 채우는 태그에서 충분히 사용 가능할 것으로 예상된다

# %% [markdown]
# ---

# %% [markdown]
# # 3. 노래 없고 태그만 있는것은 클러스터링으로 채워보자

# %%
#재실행 위한 코드
with open("./res/val.json", encoding = 'utf-8') as json_file: valid = json.load(json_file)
valid = pd.DataFrame(valid)

# %%
valid_tago_songx=valid
valid_tago_songx
# Out:
#                               tags      id plylst_title  \
# 0                               []  118598
# 1                               []  131447       앨리스테이블
# 2                               []   51464
# 3                               []   45144
# 4                               []   79929
# ...                            ...     ...          ...
# 23010                        [잔잔한]  101722
# 23011  [어머니, 힘들때, 아빠, 가족, 위로받고싶을때]  122127
# 23012                           []   77438
# 23013                           []   36231
# 23014                           []   65189
#
#                                                    songs  like_cnt  \
# 0      [373313, 151080, 275346, 696876, 165237, 52593...      1675
# 1                                                     []         1
# 2      [529437, 516103, 360067, 705713, 226062, 37089...        62
# 3      [589668, 21711, 570151, 320043, 13930, 599327,...        20
# 4      [672718, 121924, 102694, 683657, 201558, 38511...        20
# ...                                                  ...       ...
# 23010  [75842, 26083, 244183, 684715, 500593, 508608,...        17
# 23011  [450275, 487671, 561031, 663944, 628672, 59121...        10
# 23012  [625875, 464051, 11657, 236393, 358186, 213435...         0
# 23013  [161094, 665833, 688145, 432735, 439938, 12665...        31
# 23014  [643070, 132994, 98223, 293236, 513129, 650494...        19
#
#                      updt_date
# 0      2019-05-27 14:14:33.000
# 1      2014-07-16 15:24:24.000
# 2      2008-06-21 23:26:22.000
# 3      2017-10-30 18:15:43.000
# 4      2017-02-07 11:40:42.000
# ...                        ...
# 23010  2015-12-17 14:06:05.000
# 23011  2020-04-16 21:35:44.000
# 23012  2019-03-27 15:27:40.000
# 23013  2015-11-18 11:49:09.000
# 23014  2017-04-23 16:50:58.000
#
# [23015 rows x 6 columns]

# %%
#index 찾기 test

#valid_tago_songx['tags'][23010][0] : 잔잔한
#tag_tf_gnrmap[tag_tf_gnrmap['tags']==valid_tago_songx['tags'][23010][0]]# : tags 잔잔한 있는 배열
i=tag_tf_gnrmap[tag_tf_gnrmap['tags']==valid_tago_songx['tags'][23010][0]]['labels'].to_frame()
i=i.reset_index()
i['labels'][0]
can_list=tag_tf_gnrmap.loc[tag_tf_gnrmap['labels']==i['labels'][0]].head(11).reset_index()
testlist=['잔잔한']
for j in range(0,11):
    if(len(testlist)==10):
        break;
    testlist.append(can_list['tags'][j])
    
    
testlist
# Out:
# ['잔잔한', '기분전환', '감성', '휴식', '잔잔한', '드라이브', '힐링', '사랑', '새벽', '밤']

# %%
#max test
testlist2=['안녕','하세요','안녕','안녕']

testlist3=[1,1,2,2,3,3,3]

testlist4=[1,2,3,4,5]
print(max(testlist2),max(testlist3),max(testlist4))
# Out:
# 하세요 3 5

# %% [markdown]
# ### 문자엔 적용안되고, 중복있을땐 맨 마지막 값이 나오는듯???
#
# ### 일단 이걸 쓰고 중복은 보강하는 방향으로 해야할듯..

# %%
# 노래 X 태그 O 검색 방법 -- 세어보니 2630개, 그중 태그 1개만 딱 있는건 41개, 2~9개 1539개, 10개 꽉 채워진경우 1050개
# 빈배열이 있다고해서 isnull로 걸러지지 않는다ㅠ
error_list=[] #노래0개 태그 1개일때 오류 리스트
error_list2=[] #노래x태그만 있는 것들 중 train에 없는 태그가 있는 경우
error_list3=[] #노래x 태그가 여러개 있으나 단 하나도 train에 없다!

perform=[]

for i in range(0,23015):
    if valid_tago_songx['tags'][i] and not valid_tago_songx['songs'][i]:#tag가 있고, song이 비어 있을 때
        
        #태그 10개 채워야함, tl=tag_length
        need_tl=10-len(valid_tago_songx['tags'][i])
        
        #태그가 딱 1개 있을 때: 
        if(need_tl==9):
            
            try:
                #### 주의사항 top10에 1개있는 태그가 있을수도있고 없을수도 있음.-->set을 이용하면 배열에서 중복없애기 가능
                num=tag_tf_gnrmap[tag_tf_gnrmap['tags']==valid_tago_songx['tags'][i][0]]['labels'].to_frame()
                num=num.reset_index()
                #num['labels'][0]
                can_list=tag_tf_gnrmap.loc[tag_tf_gnrmap['labels']==num['labels'][0]].head(11).reset_index()
                for j in range(0,11):
                    if can_list['tags'][j] not in valid_tago_songx['tags'][i]: #포함되지 않으면
                        valid_tago_songx['tags'][i].append(can_list['tags'][j])
                    
                    # 순서가 섞이지 않게 하되 중복검사를 해야하므로 set적용한걸로 개수를 세어본다.(원본 안바뀜)
                    if(len(list(set(valid_tago_songx['tags'][i])))==10): 
                        break;
                    
            except:
                error_list.append(i)
        
        ##태그가 있긴 하나 8~1개만 더 채워넣으면 되는 경우
        elif(need_tl>0):  
            nlist=[]
            try:
                for p in range(0,len(valid_tago_songx['tags'][i])):
                    try:
                        num=tag_tf_gnrmap[tag_tf_gnrmap['tags']==valid_tago_songx['tags'][i][p]]['labels'].to_frame()
                        num=num.reset_index()
                        nlist.append(num['labels'][0])
                    except:
                        if i not in error_list2: #중복인 경우 제외
                            error_list2.append(i)
                
                can_list=tag_tf_gnrmap.loc[tag_tf_gnrmap['labels']==max(nlist)].head(11).reset_index()
                for j in range(0,11):
                    if can_list['tags'][j] not in valid_tago_songx['tags'][i]: #포함되지 않으면
                        valid_tago_songx['tags'][i].append(can_list['tags'][j])
                        
                    # 순서가 섞이지 않게 하되 중복검사를 해야하므로 set적용한걸로 개수를 세어본다.(원본 안바뀜)
                    if(len(list(set(valid_tago_songx['tags'][i])))==10): 
                        break;
                perform.append(i)    
                    
            except: #혹시모를것 대비(비어있어야정상!)
                error_list3.append(i)
            
            #print(nlist)
            #출력해본 결과 집합이 중복되는 것이 꽤 많았다. 따라서 배열에서 가장 많은 집합을 기준으로 삼고자 한다.
valid_tago_songx
# Out:
#                               tags      id plylst_title  \
# 0                               []  118598
# 1                               []  131447       앨리스테이블
# 2                               []   51464
# 3                               []   45144
# 4                               []   79929
# ...                            ...     ...          ...
# 23010                        [잔잔한]  101722
# 23011  [어머니, 힘들때, 아빠, 가족, 위로받고싶을때]  122127
# 23012                           []   77438
# 23013                           []   36231
# 23014                           []   65189
#
#                                                    songs  like_cnt  \
# 0      [373313, 151080, 275346, 696876, 165237, 52593...      1675
# 1                                                     []         1
# 2      [529437, 516103, 360067, 705713, 226062, 37089...        62
# 3      [589668, 21711, 570151, 320043, 13930, 599327,...        20
# 4      [672718, 121924, 102694, 683657, 201558, 38511...        20
# ...                                                  ...       ...
# 23010  [75842, 26083, 244183, 684715, 500593, 508608,...        17
# 23011  [450275, 487671, 561031, 663944, 628672, 59121...        10
# 23012  [625875, 464051, 11657, 236393, 358186, 213435...         0
# 23013  [161094, 665833, 688145, 432735, 439938, 12665...        31
# 23014  [643070, 132994, 98223, 293236, 513129, 650494...        19
#
#                      updt_date
# 0      2019-05-27 14:14:33.000
# 1      2014-07-16 15:24:24.000
# 2      2008-06-21 23:26:22.000
# 3      2017-10-30 18:15:43.000
# 4      2017-02-07 11:40:42.000
# ...                        ...
# 23010  2015-12-17 14:06:05.000
# 23011  2020-04-16 21:35:44.000
# 23012  2019-03-27 15:27:40.000
# 23013  2015-11-18 11:49:09.000
# 23014  2017-04-23 16:50:58.000
#
# [23015 rows x 6 columns]

# %% [markdown]
# ---
# # 결과 확인해보기

# %%
#작동한경우
perform
# Out:
# [20,
#  40,
#  43,
#  49,
#  55,
#  56,
#  58,
#  81,
#  82,
#  96,
#  108,
#  136,
#  139,
#  140,
#  181,
#  209,
#  215,
#  226,
#  266,
#  267,
#  277,
#  283,
#  302,
#  337,
#  340,
#  356,
#  365,
#  366,
#  380,
#  387,
#  397,
#  404,
#  405,
#  409,
#  411,
#  422,
#  458,
#  461,
#  477,
#  484,
#  499,
#  527,
#  528,
#  531,
#  552,
#  557,
#  560,
#  599,
#  604,
#  619,
#  623,
#  625,
#  658,
#  661,
#  700,
#  702,
#  711,
#  721,
#  730,
#  773,
#  782,
#  801,
#  806,
#  811,
#  883,
#  884,
#  896,
#  897,
#  916,
#  927,
#  948,
#  979,
#  987,
#  988,
#  989,
#  996,
#  1010,
#  1020,
#  1061,
#  1096,
#  1101,
#  1106,
#  1109,
#  1124,
#  1143,
#  1167,
#  1168,
#  1174,
#  1177,
#  1196,
#  1205,
#  1209,
#  1244,
#  1249,
#  1257,
#  1264,
#  1298,
#  1303,
#  1304,
#  1313,
#  1323,
#  1342,
#  1367,
#  1368,
#  1400,
#  1408,
#  1411,
#  1412,
#  1432,
#  1441,
#  1463,
#  1468,
#  1470,
#  1485,
#  1525,
#  1563,
#  1566,
#  1575,
#  1602,
#  1616,
#  1624,
#  1679,
#  1683,
#  1692,
#  1698,
#  1724,
#  1725,
#  1778,
#  1780,
#  1787,
#  1814,
#  1815,
#  1816,
#  1834,
#  1837,
#  1856,
#  1871,
#  1881,
#  1888,
#  1890,
#  1897,
#  1907,
#  1912,
#  1948,
#  1955,
#  1958,
#  1970,
#  1975,
#  1976,
#  2001,
#  2012,
#  2015,
#  2019,
#  2028,
#  2031,
#  2037,
#  2098,
#  2137,
#  2140,
#  2194,
#  2205,
#  2222,
#  2225,
#  2234,
#  2249,
#  2255,
#  2276,
#  2284,
#  2314,
#  2318,
#  2332,
#  2382,
#  2386,
#  2398,
#  2430,
#  2433,
#  2434,
#  2438,
#  2448,
#  2457,
#  2464,
#  2470,
#  2479,
#  2493,
#  2514,
#  2521,
#  2529,
#  2539,
#  2549,
#  2554,
#  2558,
#  2567,
#  2575,
#  2581,
#  2582,
#  2593,
#  2606,
#  2611,
#  2622,
#  2625,
#  2634,
#  2638,
#  2645,
#  2650,
#  2685,
#  2692,
#  2719,
#  2720,
#  2732,
#  2745,
#  2820,
#  2821,
#  2848,
#  2881,
#  2903,
#  2972,
#  2980,
#  2996,
#  3000,
#  3012,
#  3024,
#  3035,
#  3039,
#  3045,
#  3058,
#  3060,
#  3062,
#  3086,
#  3105,
#  3114,
#  3144,
#  3150,
#  3163,
#  3168,
#  3186,
#  3187,
#  3191,
#  3216,
#  3217,
#  3242,
#  3256,
#  3279,
#  3280,
#  3291,
#  3332,
#  3361,
#  3382,
#  3397,
#  3435,
#  3456,
#  3457,
#  3462,
#  3466,
#  3468,
#  3489,
#  3492,
#  3496,
#  3505,
#  3511,
#  3517,
#  3522,
#  3530,
#  3547,
#  3585,
#  3605,
#  3609,
#  3625,
#  3643,
#  3668,
#  3694,
#  3710,
#  3718,
#  3720,
#  3741,
#  3742,
#  3745,
#  3748,
#  3751,
#  3779,
#  3788,
#  3803,
#  3809,
#  3848,
#  3858,
#  3859,
#  3868,
#  3872,
#  3873,
#  3919,
#  3935,
#  3968,
#  3985,
#  3986,
#  3991,
#  4016,
#  4022,
#  4047,
#  4052,
#  4081,
#  4126,
#  4157,
#  4163,
#  4166,
#  4188,
#  4207,
#  4215,
#  4230,
#  4272,
#  4279,
#  4280,
#  4323,
#  4391,
#  4395,
#  4440,
#  4451,
#  4467,
#  4486,
#  4492,
#  4509,
#  4567,
#  4575,
#  4589,
#  4612,
#  4620,
#  4652,
#  4657,
#  4667,
#  4697,
#  4705,
#  4717,
#  4719,
#  4729,
#  4735,
#  4747,
#  4752,
#  4760,
#  4784,
#  4803,
#  4807,
#  4810,
#  4819,
#  4847,
#  4867,
#  4876,
#  4897,
#  4899,
#  4912,
#  4952,
#  4970,
#  4992,
#  5011,
#  5015,
#  5038,
#  5059,
#  5071,
#  5073,
#  5101,
#  5110,
#  5131,
#  5179,
#  5183,
#  5228,
#  5248,
#  5263,
#  5268,
#  5272,
#  5278,
#  5294,
#  5297,
#  5318,
#  5351,
#  5367,
#  5383,
#  5387,
#  5404,
#  5412,
#  5426,
#  5455,
#  5475,
#  5509,
#  5526,
#  5532,
#  5557,
#  5597,
#  5679,
#  5733,
#  5736,
#  5737,
#  5770,
#  5771,
#  5772,
#  5788,
#  5791,
#  5803,
#  5823,
#  5827,
#  5839,
#  5844,
#  5846,
#  5848,
#  5910,
#  5921,
#  5937,
#  5947,
#  5950,
#  5971,
#  5991,
#  5997,
#  6018,
#  6020,
#  6046,
#  6057,
#  6076,
#  6096,
#  6130,
#  6159,
#  6160,
#  6270,
#  6275,
#  6296,
#  6304,
#  6306,
#  6307,
#  6323,
#  6335,
#  6353,
#  6378,
#  6379,
#  6395,
#  6415,
#  6427,
#  6454,
#  6455,
#  6466,
#  6477,
#  6509,
#  6520,
#  6533,
#  6537,
#  6543,
#  6558,
#  6566,
#  6584,
#  6592,
#  6618,
#  6625,
#  6637,
#  6694,
#  6721,
#  6779,
#  6788,
#  6814,
#  6821,
#  6830,
#  6837,
#  6849,
#  6859,
#  6876,
#  6880,
#  6888,
#  6897,
#  6915,
#  6916,
#  6937,
#  6977,
#  6983,
#  7002,
#  7007,
#  7010,
#  7013,
#  7016,
#  7020,
#  7022,
#  7050,
#  7052,
#  7066,
#  7082,
#  7085,
#  7107,
#  7111,
#  7161,
#  7199,
#  7211,
#  7223,
#  7240,
#  7241,
#  7286,
#  7294,
#  7298,
#  7353,
#  7380,
#  7388,
#  7395,
#  7432,
#  7470,
#  7483,
#  7493,
#  7512,
#  7514,
#  7551,
#  7553,
#  7574,
#  7612,
#  7634,
#  7642,
#  7665,
#  7669,
#  7712,
#  7776,
#  7846,
#  7854,
#  7870,
#  7879,
#  7880,
#  7912,
#  7927,
#  7946,
#  7968,
#  7986,
#  7991,
#  8002,
#  8019,
#  8040,
#  8041,
#  8049,
#  8052,
#  8073,
#  8078,
#  8098,
#  8117,
#  8129,
#  8172,
#  8174,
#  8209,
#  8219,
#  8238,
#  8265,
#  8272,
#  8274,
#  8281,
#  8283,
#  8313,
#  8314,
#  8337,
#  8367,
#  8368,
#  8376,
#  8398,
#  8416,
#  8418,
#  8425,
#  8430,
#  8432,
#  8453,
#  8465,
#  8472,
#  8475,
#  8477,
#  8491,
#  8494,
#  8496,
#  8503,
#  8507,
#  8509,
#  8510,
#  8514,
#  8517,
#  8522,
#  8537,
#  8544,
#  8551,
#  8566,
#  8584,
#  8607,
#  8637,
#  8642,
#  8646,
#  8665,
#  8670,
#  8676,
#  8685,
#  8730,
#  8747,
#  8770,
#  8775,
#  8817,
#  8823,
#  8839,
#  8846,
#  8870,
#  8899,
#  8947,
#  8983,
#  8990,
#  9016,
#  9022,
#  9025,
#  9044,
#  9076,
#  9111,
#  9158,
#  9187,
#  9192,
#  9212,
#  9227,
#  9235,
#  9236,
#  9263,
#  9265,
#  9266,
#  9270,
#  9275,
#  9286,
#  9289,
#  9300,
#  9322,
#  9325,
#  9353,
#  9379,
#  9395,
#  9427,
#  9432,
#  9433,
#  9439,
#  9440,
#  9455,
#  9457,
#  9464,
#  9477,
#  9514,
#  9518,
#  9524,
#  9528,
#  9540,
#  9560,
#  9566,
#  9575,
#  9633,
#  9656,
#  9657,
#  9660,
#  9675,
#  9695,
#  9708,
#  9709,
#  9712,
#  9714,
#  9726,
#  9728,
#  9730,
#  9750,
#  9751,
#  9758,
#  9766,
#  9771,
#  9773,
#  9811,
#  9813,
#  9821,
#  9828,
#  9835,
#  9850,
#  9862,
#  9866,
#  9890,
#  9898,
#  9901,
#  9913,
#  9918,
#  9930,
#  9953,
#  9955,
#  9963,
#  9990,
#  10033,
#  10038,
#  10051,
#  10076,
#  10083,
#  10087,
#  10099,
#  10185,
#  10219,
#  10222,
#  10289,
#  10305,
#  10308,
#  10309,
#  10363,
#  10393,
#  10402,
#  10416,
#  10480,
#  10495,
#  10505,
#  10606,
#  10614,
#  10617,
#  10632,
#  10638,
#  10641,
#  10646,
#  10651,
#  10721,
#  10738,
#  10762,
#  10763,
#  10770,
#  10771,
#  10772,
#  10777,
#  10788,
#  10792,
#  10807,
#  10827,
#  10829,
#  10838,
#  10846,
#  10870,
#  10903,
#  10939,
#  10943,
#  10970,
#  10982,
#  11034,
#  11037,
#  11048,
#  11053,
#  11078,
#  11079,
#  11086,
#  11089,
#  11096,
#  11109,
#  11111,
#  11136,
#  11146,
#  11151,
#  11159,
#  11161,
#  11163,
#  11166,
#  11169,
#  11211,
#  11307,
#  11379,
#  11385,
#  11411,
#  11417,
#  11436,
#  11437,
#  11447,
#  11461,
#  11463,
#  11464,
#  11473,
#  11475,
#  11477,
#  11493,
#  11506,
#  11539,
#  11541,
#  11562,
#  11569,
#  11617,
#  11648,
#  11658,
#  11664,
#  11678,
#  11679,
#  11708,
#  11719,
#  11747,
#  11759,
#  11769,
#  11781,
#  11806,
#  11824,
#  11866,
#  11878,
#  11879,
#  11884,
#  11895,
#  11908,
#  11913,
#  11922,
#  11928,
#  11963,
#  11965,
#  11996,
#  12074,
#  12085,
#  12106,
#  12110,
#  12121,
#  12172,
#  12180,
#  12190,
#  12213,
#  12236,
#  12253,
#  12279,
#  12294,
#  12312,
#  12345,
#  12366,
#  12409,
#  12440,
#  12450,
#  12453,
#  12475,
#  12482,
#  12492,
#  12496,
#  12500,
#  12546,
#  12588,
#  12591,
#  12595,
#  12629,
#  12652,
#  12653,
#  12654,
#  12659,
#  12665,
#  12681,
#  12731,
#  12733,
#  12736,
#  12759,
#  12763,
#  12764,
#  12768,
#  12773,
#  12782,
#  12783,
#  12786,
#  12795,
#  12832,
#  12856,
#  12865,
#  12882,
#  12900,
#  12931,
#  12989,
#  13028,
#  13035,
#  13047,
#  13054,
#  13056,
#  13065,
#  13077,
#  13166,
#  13184,
#  13185,
#  13192,
#  13194,
#  13197,
#  13198,
#  13234,
#  13236,
#  13244,
#  13278,
#  13303,
#  13312,
#  13321,
#  13332,
#  13345,
#  13361,
#  13362,
#  13364,
#  13377,
#  13389,
#  13413,
#  13422,
#  13444,
#  13452,
#  13460,
#  13470,
#  13507,
#  13509,
#  13529,
#  13545,
#  13602,
#  13623,
#  13648,
#  13670,
#  13676,
#  13708,
#  13768,
#  13794,
#  13812,
#  13822,
#  13824,
#  13851,
#  13872,
#  13874,
#  13879,
#  13901,
#  13908,
#  13916,
#  13920,
#  13959,
#  13975,
#  14024,
#  14027,
#  14049,
#  14080,
#  14084,
#  14097,
#  14120,
#  14121,
#  14144,
#  14148,
#  14150,
#  14178,
#  14192,
#  14250,
#  14254,
#  14260,
#  14277,
#  14308,
#  14313,
#  14374,
#  14435,
#  14490,
#  14545,
#  14551,
#  14582,
#  14606,
#  14620,
#  14634,
#  14640,
#  14677,
#  14692,
#  14693,
#  14723,
#  14753,
#  14767,
#  14794,
#  14803,
#  14804,
#  14808,
#  14815,
#  14817,
#  14832,
#  14848,
#  14850,
#  14857,
#  14879,
#  14881,
#  14882,
#  14914,
#  14923,
#  14937,
#  14943,
#  14962,
#  14974,
#  14985,
#  14992,
#  14998,
#  15003,
#  15014,
#  15023,
#  15028,
#  15048,
#  15064,
#  15070,
#  15077,
#  15115,
#  15158,
#  15169,
#  15174,
#  15229,
#  15258,
#  15264,
#  15271,
#  15308,
#  15318,
#  15327,
#  15343,
#  15351,
#  15354,
#  15360,
#  15364,
#  15365,
#  15369,
#  15375,
#  15399,
#  15411,
#  15422,
#  15426,
#  15446,
#  15454,
#  15457,
#  15472,
#  15499,
#  15500,
#  15528,
#  15554,
#  ...]

# %%
valid_tago_songx['tags'][81]
# Out:
# ['달래주는', '연인', '연애', '사랑', '프로포즈', '힙합', '취향저격', '저녁', '집중', '감각적인']

# %% [markdown]
# 들어간걸 확인 가능
#
# ---

# %%
#태그가 여러개 있었어나 단 하나도 안맞는경우
error_list3
# Out:
# [160, 573, 1133, 5450, 6928, 13373, 14740, 19162, 21182, 22841]

# %%
valid_tago_songx['tags'][6928]
# Out:
# ['가슴답답_할_때', '스트레스해소곡', '가슴뿡뚫리는곡']

# %% [markdown]
# ---

# %%
error_list2 #error_list3에서 걸리지 않는다면 괜찮다...
# Out:
# [20,
#  160,
#  477,
#  484,
#  528,
#  573,
#  721,
#  884,
#  916,
#  1133,
#  1174,
#  1196,
#  1368,
#  1408,
#  1411,
#  1525,
#  1780,
#  1815,
#  1888,
#  1955,
#  1975,
#  2019,
#  2234,
#  2249,
#  2438,
#  2581,
#  2720,
#  3012,
#  3105,
#  3280,
#  3605,
#  3741,
#  3779,
#  3788,
#  3868,
#  3935,
#  4188,
#  4492,
#  4589,
#  4667,
#  4735,
#  4899,
#  5248,
#  5272,
#  5278,
#  5318,
#  5450,
#  5788,
#  5910,
#  5950,
#  5997,
#  6454,
#  6721,
#  6928,
#  7022,
#  7353,
#  7493,
#  7912,
#  8272,
#  8281,
#  8283,
#  8314,
#  8418,
#  8537,
#  8670,
#  8983,
#  9016,
#  9212,
#  9227,
#  9379,
#  9695,
#  9730,
#  9750,
#  9913,
#  9918,
#  10076,
#  10185,
#  10505,
#  10606,
#  10846,
#  10939,
#  11096,
#  11109,
#  11146,
#  11161,
#  11562,
#  11708,
#  11747,
#  12074,
#  12085,
#  12900,
#  12931,
#  13373,
#  13545,
#  13794,
#  13874,
#  13908,
#  13975,
#  14027,
#  14308,
#  14740,
#  14832,
#  14848,
#  14857,
#  14881,
#  14937,
#  15003,
#  15158,
#  15472,
#  15570,
#  15741,
#  15792,
#  15810,
#  16158,
#  16487,
#  16596,
#  16732,
#  17079,
#  17188,
#  17249,
#  17295,
#  17703,
#  17735,
#  17744,
#  17808,
#  18187,
#  18294,
#  18330,
#  18354,
#  18397,
#  18477,
#  18680,
#  18913,
#  18959,
#  18994,
#  19162,
#  19341,
#  19551,
#  19689,
#  19697,
#  19821,
#  19903,
#  20122,
#  20309,
#  21003,
#  21180,
#  21182,
#  21492,
#  21580,
#  21819,
#  22034,
#  22166,
#  22214,
#  22324,
#  22370,
#  22654,
#  22841]

# %% [markdown]
# ---

# %%
## valid에 tag 1개있는것 중 train에 없던 tag들
error_list
# Out:
# [104,
#  109,
#  659,
#  684,
#  1744,
#  2346,
#  2831,
#  3427,
#  4048,
#  4149,
#  4628,
#  5693,
#  6060,
#  6723,
#  7713,
#  7962,
#  9130,
#  9413,
#  10035,
#  10424,
#  11069,
#  11129,
#  11178,
#  11346,
#  12372,
#  12593,
#  12723,
#  14674,
#  15183,
#  16408,
#  17428,
#  18105,
#  18249,
#  18900,
#  20641,
#  20881,
#  20888,
#  21759,
#  22133,
#  22549,
#  22906]

# %%
#없는애 예시
valid_tago_songx['tags'][6060]
# Out:
# ['청춘2부작']

# %%
valid_tago_songx[6060:]
# Out:
#                               tags      id plylst_title  \
# 6060                       [청춘2부작]   48551    화양연화 pt.2
# 6061             [Metal, M에센셜, 메탈]   24470
# 6062                       [힐링, 밤]   91765
# 6063                    [남자싱어송라이터]    5270
# 6064                            []  116661
# ...                            ...     ...          ...
# 23010                        [잔잔한]  101722
# 23011  [어머니, 힘들때, 아빠, 가족, 위로받고싶을때]  122127
# 23012                           []   77438
# 23013                           []   36231
# 23014                           []   65189
#
#                                                    songs  like_cnt  \
# 6060                                                  []         0
# 6061   [224031, 103782, 567488, 328751, 398547, 45503...        11
# 6062   [477964, 120626, 274716, 231563, 71243, 400157...         8
# 6063   [405855, 369146, 685550, 27208, 170937, 117402...      1391
# 6064                            [625200, 501822, 532347]         0
# ...                                                  ...       ...
# 23010  [75842, 26083, 244183, 684715, 500593, 508608,...        17
# 23011  [450275, 487671, 561031, 663944, 628672, 59121...        10
# 23012  [625875, 464051, 11657, 236393, 358186, 213435...         0
# 23013  [161094, 665833, 688145, 432735, 439938, 12665...        31
# 23014  [643070, 132994, 98223, 293236, 513129, 650494...        19
#
#                      updt_date
# 6060   2017-03-23 09:44:06.000
# 6061   2016-07-06 16:27:11.000
# 6062   2014-08-06 11:53:28.000
# 6063   2017-04-10 12:33:48.000
# 6064   2017-09-25 14:38:56.000
# ...                        ...
# 23010  2015-12-17 14:06:05.000
# 23011  2020-04-16 21:35:44.000
# 23012  2019-03-27 15:27:40.000
# 23013  2015-11-18 11:49:09.000
# 23014  2017-04-23 16:50:58.000
#
# [16955 rows x 6 columns]
