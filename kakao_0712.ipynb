# %% [markdown]
# playlist 노래 장르 파악하기

# %%
import pandas as pd
train_data= pd.read_csv(r'C:\Users\jmlee\Desktop\kakao_arena\csv_data\train.csv')
song_meta= pd.read_csv(r'C:\Users\jmlee\Desktop\kakao_arena\csv_data\song_meta.csv')
genre= pd.read_csv(r'C:\Users\jmlee\Desktop\kakao_arena\csv_data\genre.csv')
train_data
# Out:
#         Unnamed: 0                                               tags      id  \
# 0                0                                              ['락']   61281
# 1                1                                       ['추억', '회상']   10532
# 2                2                                      ['까페', '잔잔한']   76951
# 3                3  ['연말', '눈오는날', '캐럴', '분위기', '따듯한', '크리스마스캐럴', ...  147456
# 4                4                                             ['댄스']   27616
# ...            ...                                                ...     ...
# 115066      115066  ['록메탈', '밴드사운드', '록', '락메탈', '메탈', '락', 'extre...  120325
# 115067      115067                                             ['일렉']  106976
# 115068      115068  ['담시', '가족', '눈물', '그리움', '주인공', '나의_이야기', '사랑...   11343
# 115069      115069          ['잔잔한', '버스', '퇴근버스', 'Pop', '풍경', '퇴근길']  131982
# 115070      115070                     ['노래추천', '팝송추천', '팝송', '팝송모음']  100389
#
# ...

# %%
song=train_data["songs"][0].replace("[","").replace("]","")
list_str = song.split(",")
list_str[:]
# Out:
# ['525514',
#  ' 129701',
#  ' 383374',
#  ' 562083',
#  ' 297861',
#  ' 139541',
#  ' 351214',
#  ' 650298',
#  ' 531057',
#  ' 205238',
#  ' 706183',
#  ' 127099',
#  ' 660493',
#  ' 461973',
#  ' 121455',
#  ' 72552',
#  ' 223955',
#  ' 324992',
#  ' 50104']

# %%
int(list_str[0])
# Out:
# 525514

# %%
length=len(list_str)
a=[]
for i in range(0,length-1):
    new_data=song_meta.loc[song_meta.id==int(list_str[i]),['id','song_gn_dtl_gnr_basket','song_name']] #플레이리스트별 장르  type=df

# %%
new_data
# Out:
#             id song_gn_dtl_gnr_basket  song_name
# 324992  324992             ['GN0901']  If We Try
